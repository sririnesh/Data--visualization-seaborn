# %% [markdown]
# # importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# C:\Users\sripriya\AppData\Local\Temp\ipykernel_7476\328324305.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# # importing the dataset

# %%
dataset=pd.read_csv('Placement_Data_Full_Class.csv')

# %%
dataset
# Out:
#      Sno Gender  10th % SSC Board  12th % HSC Board 12th Stream  Degree %  \
# 0      1      M   67.00    Others   91.00    Others    Commerce     58.00
# 1      2      M   79.33   Central   78.33    Others     Science     77.48
# 2      3      M   65.00   Central   68.00   Central        Arts     64.00
# 3      4      M   56.00   Central   52.00   Central     Science     52.00
# 4      5      M   85.80   Central   73.60   Central    Commerce     73.30
# ..   ...    ...     ...       ...     ...       ...         ...       ...
# 210  211      M   80.60    Others   82.00    Others    Commerce     77.60
# 211  212      M   58.00    Others   60.00    Others     Science     72.00
# 212  213      M   67.00    Others   67.00    Others    Commerce     73.00
# 213  214      F   74.00    Others   66.00    Others    Commerce     58.00
# 214  215      M   62.00   Central   58.00    Others     Science     53.00
#
#     Degree stream Work exp specialisation  Mba %      status    salary
# ...

# %%
# number of rows and columns
print("The Number of Row:",dataset.shape[0])
print("The Number of columns:",dataset.shape[1])
# Out:
# The Number of Row: 215
# The Number of columns: 14

# %% [markdown]
# # univariate Analysis

# %%
import seaborn as sb
sb.distplot(dataset["10th %"],hist=True,kde_kws={"color":"red"})
# Out:
# C:\Users\sripriya\AppData\Local\Temp\ipykernel_7476\3587904908.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(dataset["10th %"],hist=True,kde_kws={"color":"red"})
# <Axes: xlabel='10th %', ylabel='Density'>

# %% [markdown]
# # Bivariate Analysis: Distribution plot

# %%
sb.jointplot(x= "10th %",y= "salary",data=dataset)
plt.show()

# %%
sb.jointplot(x= "10th %",y= "salary",data=dataset,kind="hex")
plt.show()

# %%
sb.jointplot(x= "10th %",y= "salary",data=dataset,kind="kde")
plt.show()

# %%
#pair plot

# %%
sb.pairplot(dataset,hue="Gender",diag_kind="kde",kind="scatter",palette="husl")
plt.show()

# %% [markdown]
# # For categorical plot

# %%
sb.stripplot(x= "SSC Board",y= "10th %",data=dataset)
plt.show()

# %%
sb.stripplot(x= "Gender",y= "10th %",data=dataset,jitter=True)
plt.show()

# %%
sb.swarmplot(x= "SSC Board",y= "10th %",data=dataset)
plt.show()

# %% [markdown]
# # Distribution observation

# %%
sb.violinplot(x= "Gender",y= "10th %",data=dataset)
plt.show()

# %%
sb.violinplot(x= "SSC Board",y= "10th %",data=dataset,hue="Gender")
plt.show()

# %%
sb.boxplot(x= "SSC Board",y= "10th %",data=dataset,hue="Gender")
plt.show()

# %%
#Bar plot

# %%
sb.barplot(x= "SSC Board",y= "10th %",data=dataset,hue="Gender")
plt.show()

# %%
sb.countplot(x= "SSC Board",data=dataset,hue="Gender")
plt.show()

# %%
sb.pointplot(x= "SSC Board",y= "10th %",data=dataset,hue="Gender")
plt.show()

# %%
sb.countplot(x= "SSC Board",data=dataset,hue="Gender")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
df=sb.load_dataset("excercise")
sb.factorplot(x="time",y="pulse",hue="kind",kind="violin",col="diet",data=df);
plt.show
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 4
#       2 import matplotlib.pyplot as plt
#       3 import pandas as pd
# ----> 4 df=sb.load_dataset("excercise")
#       5 sb.factorplot(x="time",y="pulse",hue="kind",kind="violin",col="diet",data=df);
#       6 plt.show
#
# File ~\.conda\envs\aiml\Lib\site-packages\seaborn\utils.py:573, in load_dataset(name, cache, data_home, **kws)
#     571 if not os.path.exists(cache_path):
#     572     if name not in get_dataset_names():
# --> 573         raise ValueError(f"'{name}' is not one of the example datasets.")
#     574     urlretrieve(url, cache_path)
#     575 full_path = cache_path
#
# ValueError: 'excercise' is not one of the example datasets.
